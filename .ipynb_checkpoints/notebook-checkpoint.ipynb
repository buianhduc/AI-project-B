# %%
import pandas as pd
import json

# %%
# %pip install pandas jinja2
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 13.1 MB/s eta 0:00:00 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 13.1 MB/s eta 0:00:00a 0:00:01
# ...
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
global data
with open("win.json", "r") as f:
    data = json.load(f)

df = pd.DataFrame(data["data"])

# %%
df
# Out:
#     round         red_agent        blue_agent  \
# 0       0  ABAgentWithCache  ABAgentWithCache
# 1       0  ABAgentWithCache       GreedyAgent
# 2       0  ABAgentWithCache       RandomAgent
# 3       0  ABAgentWithCache         MCTSAgent
# 4       0  ABAgentWithCache      MinimaxAgent
# 5       0       GreedyAgent  ABAgentWithCache
# 6       0       GreedyAgent       GreedyAgent
# 7       0       GreedyAgent       RandomAgent
# 8       0       GreedyAgent         MCTSAgent
# 9       0       GreedyAgent      MinimaxAgent
# 10      0       RandomAgent  ABAgentWithCache
# 11      0       RandomAgent       GreedyAgent
# 12      0       RandomAgent       RandomAgent
# 13      0       RandomAgent         MCTSAgent
# 14      0       RandomAgent      MinimaxAgent
# 15      0         MCTSAgent  ABAgentWithCache
# 16      0         MCTSAgent       GreedyAgent
# 17      0         MCTSAgent       RandomAgent
# 18      0         MCTSAgent         MCTSAgent
# ...

# %%
df.pivot(index="red_agent", columns="blue_agent", values="winner_color")
# Out:
# blue_agent       ABAgentWithCache GreedyAgent MCTSAgent MinimaxAgent  \
# red_agent
# ABAgentWithCache             BLUE         RED       RED          RED
# GreedyAgent                  BLUE        BLUE       RED          RED
# MCTSAgent                    BLUE        BLUE      BLUE          RED
# MinimaxAgent                  RED        BLUE       RED          NaN
# RandomAgent                  BLUE        BLUE       RED          RED
#
# blue_agent       RandomAgent
# red_agent
# ABAgentWithCache         RED
# GreedyAgent              RED
# MCTSAgent                RED
# MinimaxAgent             RED
# RandomAgent              RED

# %%
def make_pretty(styler):
    styler.set_caption("Match Result")
    styler.background_gradient(cmap='viridis')
    # styler.set_table_styles([headers, index_style])
    return styler

df.pivot(index="red_agent", columns="blue_agent", values="winner_color").style.pipe(make_pretty)
# Out:
# <style type="text/css">
# </style>
# <table id="T_d7473">
#   <caption>Match Result</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >blue_agent</th>
#       <th id="T_d7473_level0_col0" class="col_heading level0 col0" >ABAgentWithCache</th>
#       <th id="T_d7473_level0_col1" class="col_heading level0 col1" >GreedyAgent</th>
#       <th id="T_d7473_level0_col2" class="col_heading level0 col2" >MCTSAgent</th>
#       <th id="T_d7473_level0_col3" class="col_heading level0 col3" >MinimaxAgent</th>
#       <th id="T_d7473_level0_col4" class="col_heading level0 col4" >RandomAgent</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >red_agent</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %%
# %pip install jinja2
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 get_ipython().run_line_magic('pip', 'install jinja2')
#
# File ~/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py:2482, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2480     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2481 with self.builtin_trap:
# -> 2482     result = fn(*args, **kwargs)
#    2484 # The code below prevents the output from being displayed
#    2485 # when using magics with decorator @output_can_be_silenced
#    2486 # when the last Python token in the expression is a ';'.
#    2487 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/.local/lib/python3.10/site-packages/IPython/core/magics/packaging.py:105, in PackagingMagics.pip(self, line)
#     102 else:
#     103     python = shlex.quote(python)
# ...
